# %%
from PIL import Image
from torchvision import transforms as tfs

# %%
im = Image.open('./cat.png')
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=224x224 at 0x11B23D198>

# %%
print('before scale, shape: {}'.format(im.size))
new_im = tfs.Resize()
